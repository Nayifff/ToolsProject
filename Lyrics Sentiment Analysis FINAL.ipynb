# %% [markdown]
# ## Sentiment Analysis of Lyrics of Billboard Top 100 Songs from 1965-2015

# %%
import nltk
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("billboard_lyrics_1964-2015.csv", encoding = "ISO-8859-1")
df["Lyrics"] = df["Lyrics"].apply(lambda x: str(x))

# %%
 df=df.dropna(subset=["Lyrics"])

# %% [markdown]
# #### MEAN VALENCE OVER THE YEARS (Valence describes the musical positiveness conveyed by a track)

# %%
df_audio = data_sp = pd.read_excel("spotify_project_final v2.0.xlsx")
data = df_audio[data_sp["Danceability"] !=0]

# %%
# Create a zeros array to store averages later 
a=np.zeros((14,58))

df = pd.DataFrame(data[data['Year']==1960].mean())
means = pd.DataFrame(a, columns=range(1960,2018))

for year in range(1960,2018):
    df = pd.DataFrame(data[data['Year']==year].mean())
    for i in range(0,16):
        means.ix[i,year]=df.ix[i,0]
means=means.drop([0])

index_=df.index.values
newindex = list(filter(lambda x : x != 'Year', index_))

means.index=newindex
plt.figure(figsize=(15,5))
sns.lineplot(x="Year", y="Valence", data=data, lw=2)

# %% [markdown]
# ### CONCLUSION: There has been a trend of declining positiveness in popular music!

# %% [markdown]
# ### Get List of Positive and Negative Words from ptrckprry.com

# %%
def get_pos_neg_words():
    def get_words(url):
        import requests
        words = requests.get(url).content.decode('latin-1')
        word_list = words.split('\n')
        index = 0
        while index < len(word_list):
            word = word_list[index]
            if ';' in word or not word:
                word_list.pop(index)
            else:
                index+=1
        return word_list

    #Get lists of positive and negative words
    p_url = 'http://ptrckprry.com/course/ssd/data/positive-words.txt'
    n_url = 'http://ptrckprry.com/course/ssd/data/negative-words.txt'
    positive_words = get_words(p_url)
    negative_words = get_words(n_url)
    return positive_words,negative_words

positive_words,negative_words = get_pos_neg_words()

# %% [markdown]
# ### Create function to compute sentiment

# %%
def do_pos_neg_sentiment_analysis(text_list,debug=False):
    positive_words,negative_words = get_pos_neg_words()
    from nltk import word_tokenize
    results = list()
    for text in text_list:
        cpos = cneg = lpos = lneg = 0
        for word in word_tokenize(text[1]):
            if word in positive_words:
                if debug:
                    print("Positive",word)
                cpos+=1
            if word in negative_words:
                if debug:
                    print("Negative",word)
                cneg+=1
        try:
            results.append((text[0],((cpos/len(word_tokenize(text[1])))+(cneg/len(word_tokenize(text[1]))))/2))
        except:
            pass
    return results

# do_pos_neg_sentiment_analysis([(Year,dec1)])

# %%
sentiment_list = []
for year in range(1965, 2016):
    lyrics =  df[df["Year"]==year]["Lyrics"].values
    lyrics = ' '.join(lyrics)
    sentiment =do_pos_neg_sentiment_analysis([(year,lyrics)])
    sentiment_list.append(sentiment)

# %%
final_list=[]
for i in range(len(sentiment_list)):
    year, sentiment =sentiment_list[i][0]
    final_list.append((year,sentiment))

# %%
sentiment_df = pd.DataFrame(final_list)

# %%
sentiment_df.columns = ["Year", "Average_Sentiment"]

# %% [markdown]
# ### Plot Average Sentiment By Year

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt

plt.plot(sentiment_df.Year, sentiment_df.Average_Sentiment, label='linear')
plt.title("Sentiment of Popular Music between 1965-2015")
plt.show()
